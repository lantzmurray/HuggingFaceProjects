# %% [markdown]
# <a href="https://colab.research.google.com/github/lantzmurray/HuggingFaceProjects/blob/main/Hugging_Face_3_2_Neo_Text_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
from transformers import pipeline
from transformers import AutoTokenizer
from transformers import AutoModel
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]

# %%
#generator = pipeline('text-generation',model='gpt2')
#generator('Our scent of Unicorn Sprinkle smells like Ice cream, with lemon drizzle and blueberry sugar')

# %%
#generator = pipeline('text-generation',model='gpt2-medium')
#generator('Our scent of Unicorn Sprinkle smells like Ice cream, with lemon drizzle and blueberry sugar')

# %%
generator = pipeline('text-generation',model='EleutherAI/gpt-neo-2.7B')
generator('Our scent of Unicorn Sprinkle smells like Ice cream, with lemon drizzle and blueberry sugar')
# Out:
# Downloading:   0%|          | 0.00/200 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Our scent of Unicorn Sprinkle smells like Ice cream, with lemon drizzle and blueberry sugar. Great for all ages. I am a HUGE ice cream fan! So cute and fun!\n\n(I will probably make other colors of the flowers'}]
