# %% [markdown]
# <a href="https://colab.research.google.com/github/lantzmurray/HuggingFaceProjects/blob/main/Hugging_Face_3_Text_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers
# Out:
#      |████████████████████████████████| 5.3 MB 4.8 MB/s
#      |████████████████████████████████| 7.6 MB 11.0 MB/s
#      |████████████████████████████████| 163 kB 24.4 MB/s

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
from transformers import pipeline
from transformers import AutoTokenizer
from transformers import AutoModel

# %%
generator = pipeline('text-generation',model='gpt2')
generator('Our scent of Unicorn Sprinkle smells like Ice cream, with lemon drizzle and blueberry sugar')
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Our scent of Unicorn Sprinkle smells like Ice cream, with lemon drizzle and blueberry sugar and vanilla, and chocolate caramel and nutmeg. I can't wait to try it!\n\nI love to try new things (sometimes the easiest thing"}]

# %%
generator = pipeline('text-generation',model='gpt2-medium')
generator('Our scent of Unicorn Sprinkle smells like Ice cream, with lemon drizzle and blueberry sugar')
# Out:
# Downloading:   0%|          | 0.00/718 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Our scent of Unicorn Sprinkle smells like Ice cream, with lemon drizzle and blueberry sugar. A very unique scent that will give you instant ice cream vibes after your shave. Use with any type of shaving cream, including shaving gel.'}]
